# %% [markdown]
# # Food recommendation System using Collaborative Filtering

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
menu = pd.read_csv('Test_menu.csv')
users = pd.read_csv('Test_users.csv')
ratings = pd.read_csv('Test_ratings.csv')

# %%
users.head()
# Out:
#    user_id       UserName
# 0        1        JohnDoe
# 1        2      JaneSmith
# 2        3  RobertJohnson
# 3        4     EmilyJones
# 4        5   MichaelBrown

# %%
menu.head()
# Out:
#    ItemID    Category           ItemName  \
# 0       1  Appetizers      Caprese Salad
# 1       2  Appetizers         Bruschetta
# 2       3  Appetizers      Chicken Wings
# 3       4  Appetizers  Stuffed Mushrooms
# 4       5  Appetizers    Shrimp Cocktail
#
#                                          Description   Price  \
# 0  Fresh tomatoes, mozzarella, basil, olive oil, ...  749.25
# 1  Toasted bread topped with tomatoes, garlic, ba...  636.75
# 2  Crispy fried chicken wings tossed in buffalo s...  824.25
# 3  Mushroom caps stuffed with seasoned breadcrumb...  711.75
# 4         Chilled shrimp served with cocktail sauce.  899.25
#
#                       ImageURL
# 0      caprese_salad_image.jpg
# 1         bruschetta_image.jpg
# 2      chicken_wings_image.jpg
# 3  stuffed_mushrooms_image.jpg
# 4    shrimp_cocktail_image.jpg

# %%
ratings.head()
# Out:
#    user_id  ItemID  rating
# 0        1      10       4
# 1        2      25       3
# 2        3       5       2
# 3        4      30       5
# 4        5      15       4

# %% [markdown]
# # Exploratory Data Analysis

# %%
print(menu.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (180, 6)
# (500, 2)
# (7164, 3)

# %%
menu.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 1534

# %%
menu.describe()
# Out:
#            ItemID        Price
# count  180.000000   180.000000
# mean    90.500000   790.416667
# std     52.105662   402.353794
# min      1.000000   149.250000
# 25%     45.750000   561.750000
# 50%     90.500000   718.000000
# 75%    135.250000   899.250000
# max    180.000000  2624.250000

# %%
users.describe()
# Out:
#           user_id
# count  500.000000
# mean   250.500000
# std    144.481833
# min      1.000000
# 25%    125.750000
# 50%    250.500000
# 75%    375.250000
# max    500.000000

# %%
num_cols = ratings.describe()

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(ratings[col].skew(), 2))
    plt.figure(figsize = (5, 2))
    plt.subplot(1, 2, 1)
    ratings[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=ratings[col])
    plt.show()
# Out:
# user_id
# Skew : -0.35
# ItemID
# Skew : 0.09
# rating
# Skew : 0.31

# %%
plt.figure(figsize=(15,15))
sns.pairplot(data=ratings)
plt.show()
# Out:
# /Users/varsha/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x='ItemID', data=ratings)
# Out:
# <Axes: xlabel='ItemID', ylabel='count'>

# %%
sns.barplot (x ='ItemID' , y='rating', data = ratings)
# Out:
# <Axes: xlabel='ItemID', ylabel='rating'>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(ratings.corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# # Popularity Based Recommender System

# %%
#based of items which got more than 50 ratings
ratings_with_itemname = ratings.merge(menu, on = 'ItemID')
ratings_with_itemname
# Out:
#       user_id  ItemID  rating    Category                        ItemName  \
# 0           1      10       4  Appetizers           Spinach Artichoke Dip
# 1         100      10       3  Appetizers           Spinach Artichoke Dip
# 2         103      10       4  Appetizers           Spinach Artichoke Dip
# 3         161      10       4  Appetizers           Spinach Artichoke Dip
# 4         211      10       5  Appetizers           Spinach Artichoke Dip
# ...       ...     ...     ...         ...                             ...
# 7159      296     153       7    Desserts  Chocolate Covered Strawberries
# 7160      173     175       1  Appetizers    Prosciutto-Wrapped Asparagus
# 7161      256     175       6  Appetizers    Prosciutto-Wrapped Asparagus
# 7162      299     175       6  Appetizers    Prosciutto-Wrapped Asparagus
# 7163      431     180       2  Appetizers              Caprese Bruschetta
#
#                                             Description   Price  \
# 0     Creamy dip made with spinach, artichokes, and ...  599.25
# 1     Creamy dip made with spinach, artichokes, and ...  599.25
# 2     Creamy dip made with spinach, artichokes, and ...  599.25
# 3     Creamy dip made with spinach, artichokes, and ...  599.25
# 4     Creamy dip made with spinach, artichokes, and ...  599.25
# ...                                                 ...     ...
# 7159  Fresh strawberries dipped in rich dark chocolate.  599.25
# 7160  Fresh asparagus spears wrapped in prosciutto a...  786.75
# 7161  Fresh asparagus spears wrapped in prosciutto a...  786.75
# 7162  Fresh asparagus spears wrapped in prosciutto a...  786.75
# 7163  Combination of classic bruschetta with diced t...  824.25
#
#                                     ImageURL
# 0            spinach_artichoke_dip_image.jpg
# 1            spinach_artichoke_dip_image.jpg
# 2            spinach_artichoke_dip_image.jpg
# 3            spinach_artichoke_dip_image.jpg
# 4            spinach_artichoke_dip_image.jpg
# ...                                      ...
# 7159                    dessert_image_23.jpg
# 7160  prosciutto_wrapped_asparagus_image.jpg
# 7161  prosciutto_wrapped_asparagus_image.jpg
# 7162  prosciutto_wrapped_asparagus_image.jpg
# 7163            caprese_bruschetta_image.jpg
#
# [7164 rows x 8 columns]

# %%
ratings_with_itemname.columns
# Out:
# Index(['user_id', 'ItemID', 'rating', 'Category', 'ItemName', 'Description',
#        'Price', 'ImageURL'],
#       dtype='object')

# %%
#if we have two items with similar names but different ItemID
num_rating_df = ratings_with_itemname.groupby('ItemName').count()['rating'].reset_index()
num_rating_df.rename(columns={'rating':'num_ratings'},inplace = True)

#size() counts the number of times each unique combination of "ItemName" and "Description" appears in the DataFrame.
#.to_frame() method creates a new DataFrame
# num_rating_df = ratings_with_itemname.groupby(['ItemName', 'Description']).size().to_frame(name='num_ratings').reset_index()
num_rating_df
# Out:
#                              ItemName  num_ratings
# 0                Apple Cinnamon Crisp           38
# 1                       Artichoke Dip           18
# 2                    Avocado Benedict           16
# 3                       Avocado Toast           23
# 4            BBQ Pulled Pork Sandwich          106
# ..                                ...          ...
# 175                     Veggie Burger           12
# 176          Watermelon Mint Lemonade           26
# 177                  Western Omelette           18
# 178  White Chocolate Raspberry Mousse           18
# 179                    Wine Selection           17
#
# [180 rows x 2 columns]

# %%
avg_rating_df = ratings_with_itemname.groupby('ItemName').mean(numeric_only=True)['rating'].reset_index() #ignoring non-numeric values.
avg_rating_df.rename(columns={'rating':'avg_ratings'},inplace = True)

# avg_rating_df = ratings_with_itemname.groupby(['ItemName', 'Description']).size().to_frame(name='avg_ratings').reset_index()
avg_rating_df
# Out:
#                              ItemName  avg_ratings
# 0                Apple Cinnamon Crisp     4.526316
# 1                       Artichoke Dip     4.444444
# 2                    Avocado Benedict     4.187500
# 3                       Avocado Toast     4.217391
# 4            BBQ Pulled Pork Sandwich     3.066038
# ..                                ...          ...
# 175                     Veggie Burger     3.083333
# 176          Watermelon Mint Lemonade     3.923077
# 177                  Western Omelette     4.388889
# 178  White Chocolate Raspberry Mousse     3.500000
# 179                    Wine Selection     4.470588
#
# [180 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df, on ='ItemName')
popular_df
# Out:
#                              ItemName  num_ratings  avg_ratings
# 0                Apple Cinnamon Crisp           38     4.526316
# 1                       Artichoke Dip           18     4.444444
# 2                    Avocado Benedict           16     4.187500
# 3                       Avocado Toast           23     4.217391
# 4            BBQ Pulled Pork Sandwich          106     3.066038
# ..                                ...          ...          ...
# 175                     Veggie Burger           12     3.083333
# 176          Watermelon Mint Lemonade           26     3.923077
# 177                  Western Omelette           18     4.388889
# 178  White Chocolate Raspberry Mousse           18     3.500000
# 179                    Wine Selection           17     4.470588
#
# [180 rows x 3 columns]

# %%
#top 20 popular items sorted in descending order with more than 50 user ratings(num_ratings)
popular_df = popular_df[popular_df['num_ratings']>=50].sort_values('avg_ratings',ascending = False).head(20)
popular_df
# Out:
#                       ItemName  num_ratings  avg_ratings
# 108   Molten Chocolate Soufflé           76     6.513158
# 159                   Tiramisu           55     6.327273
# 149       Stuffed Bell Peppers           51     6.098039
# 89                Key Lime Pie           60     6.066667
# 70           Fresh Fruit Juice           66     5.984848
# 9                 Banana Split           53     5.924528
# 17               Bottled Water           54     5.870370
# 153              Surf and Turf           62     5.838710
# 131            Red Velvet Cake           56     5.714286
# 172        Vegetarian Omelette           56     5.535714
# 144      Spinach Artichoke Dip           56     5.517857
# 18           Breakfast Burrito           51     5.509804
# 85                     Hot Tea           72     5.277778
# 94   Lemon Herb Grilled Salmon          115     5.243478
# 62                Crème Brûlée           60     5.233333
# 39             Chicken Marsala           65     5.200000
# 143     Spicy Thai Noodle Bowl           50     5.180000
# 10             Beef Wellington           80     5.175000
# 114                Panna Cotta           52     5.173077
# 109          Mozzarella Sticks           56     5.160714

# %%
popular_df = popular_df.merge(menu,on ='ItemName').drop_duplicates('ItemName')[['ItemName','Description', 'Price', 'ImageURL','num_ratings','avg_ratings']]
popular_df
# Out:
#                      ItemName  \
# 0    Molten Chocolate Soufflé
# 1                    Tiramisu
# 2        Stuffed Bell Peppers
# 3                Key Lime Pie
# 4           Fresh Fruit Juice
# 5                Banana Split
# 6               Bottled Water
# 7               Surf and Turf
# 8             Red Velvet Cake
# 9         Vegetarian Omelette
# 10      Spinach Artichoke Dip
# 11          Breakfast Burrito
# 12                    Hot Tea
# 13  Lemon Herb Grilled Salmon
# 14               Crème Brûlée
# 15            Chicken Marsala
# 16     Spicy Thai Noodle Bowl
# 17            Beef Wellington
# 18                Panna Cotta
# 19          Mozzarella Sticks
#
#                                           Description    Price  \
# 0   Decadent chocolate soufflé with a gooey molten...   861.75
# 1   Classic Italian dessert made with layers of co...   599.25
# 2   Bell peppers stuffed with seasoned ground beef...  1461.75
# 3   Tangy key lime filling in a graham cracker cru...   561.75
# 4           Variety of freshly squeezed fruit juices.   374.25
# 5   Scoops of vanilla, chocolate, and strawberry i...   786.75
# 6                   Bottled still or sparkling water.   149.25
# 7   Grilled steak and lobster tail served with a s...  2624.25
# 8   Moist red velvet cake layers with cream cheese...   749.25
# 9   Omelette filled with sautéed vegetables and ch...   711.75
# 10  Creamy dip made with spinach, artichokes, and ...   599.25
# 11  Flour tortilla filled with scrambled eggs, bac...   899.25
# 12                     Assorted varieties of hot tea.   224.25
# 13  Grilled salmon fillet marinated in lemon, herb...  1249.25
# 14  Rich custard topped with a layer of caramelize...   636.75
# 15  Sautéed chicken breasts in a mushroom and Mars...  1574.25
# 16  Rice noodles, vegetables, tofu or chicken, and...   899.25
# 17  Tender beef fillet topped with mushroom duxell...  2436.75
# 18  Italian dessert of sweetened cream thickened w...   674.25
# 19  Golden-fried mozzarella sticks served with mar...   561.75
#
#                            ImageURL  num_ratings  avg_ratings
# 0              dessert_image_10.jpg           76     6.513158
# 1               dessert_image_3.jpg           55     6.327273
# 2                dinner_image_9.jpg           51     6.098039
# 3               dessert_image_6.jpg           60     6.066667
# 4              beverage_image_6.jpg           66     5.984848
# 5               dessert_image_8.jpg           53     5.924528
# 6              beverage_image_8.jpg           54     5.870370
# 7                dinner_image_5.jpg           62     5.838710
# 8               dessert_image_7.jpg           56     5.714286
# 9             breakfast_image_4.jpg           56     5.535714
# 10  spinach_artichoke_dip_image.jpg           56     5.517857
# 11            breakfast_image_6.jpg           51     5.509804
# 12             beverage_image_3.jpg           72     5.277778
# 13              dinner_image_21.jpg          115     5.243478
# 14              dessert_image_5.jpg           60     5.233333
# 15               dinner_image_6.jpg           65     5.200000
# 16                lunch_image_6.jpg           50     5.180000
# 17               dinner_image_8.jpg           80     5.175000
# 18              dessert_image_9.jpg           52     5.173077
# 19      mozzarella_sticks_image.jpg           56     5.160714

# %%
data_preprocessed = ratings_with_itemname.isnull()

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
#items rated by users who have given rating more than 50 times
x = ratings_with_itemname.groupby('user_id').count()['rating'] > 50
educated_users = x[x].index
educated_users
# Out:
# Index([ 38,  44, 102, 132, 135, 194, 222, 243, 244, 283, 287, 297, 306, 326,
#        364, 376, 388, 391, 392, 399],
#       dtype='int64', name='user_id')

# %%
#rating based on users
filtered_rating = ratings_with_itemname[ratings_with_itemname['user_id'].isin(educated_users)]
filtered_rating
# Out:
#       user_id  ItemID  rating    Category                          ItemName  \
# 9          38      10       1  Appetizers             Spinach Artichoke Dip
# 19        376      10       7  Appetizers             Spinach Artichoke Dip
# 20        364      10       7  Appetizers             Spinach Artichoke Dip
# 47        297      10       5  Appetizers             Spinach Artichoke Dip
# 66        102      25       6       Lunch                Mediterranean Wrap
# ...       ...     ...     ...         ...                               ...
# 7102       38     157       3    Desserts  White Chocolate Raspberry Mousse
# 7108      364     166       4   Beverages     Ginger Turmeric Wellness Shot
# 7120      135     172       2  Appetizers           Teriyaki Salmon Skewers
# 7129      132     152       4    Desserts                     Peach Cobbler
# 7149      364     153       1    Desserts    Chocolate Covered Strawberries
#
#                                             Description   Price  \
# 9     Creamy dip made with spinach, artichokes, and ...  599.25
# 19    Creamy dip made with spinach, artichokes, and ...  599.25
# 20    Creamy dip made with spinach, artichokes, and ...  599.25
# 47    Creamy dip made with spinach, artichokes, and ...  599.25
# 66    Grilled vegetables, hummus, feta cheese, lettu...  636.75
# ...                                                 ...     ...
# 7102  Light and fluffy white chocolate mousse with a...  749.25
# 7108  Concentrated shot with ginger and turmeric for...  299.25
# 7120  Grilled salmon skewers glazed with teriyaki sa...  649.25
# 7129  Warm peach cobbler with a buttery biscuit topp...  711.75
# 7149  Fresh strawberries dipped in rich dark chocolate.  599.25
#
#                                ImageURL
# 9       spinach_artichoke_dip_image.jpg
# 19      spinach_artichoke_dip_image.jpg
# 20      spinach_artichoke_dip_image.jpg
# 47      spinach_artichoke_dip_image.jpg
# 66                    lunch_image_5.jpg
# ...                                 ...
# 7102               dessert_image_27.jpg
# 7108              beverage_image_26.jpg
# 7120  teriyaki_salmon_skewers_image.jpg
# 7129               dessert_image_22.jpg
# 7149               dessert_image_23.jpg
#
# [1702 rows x 8 columns]

# %%
#rating based on Items
y = filtered_rating.groupby('ItemName').count()['rating'] >=10
famous_items = y[y].index
famous_items
# Out:
# Index(['Apple Cinnamon Crisp', 'BBQ Pulled Pork Sandwich',
#        'Bacon-Wrapped Jalapeños', 'Black Bean and Corn Salad',
#        'Blueberry Lavender Lemonade', 'Caprese Salad', 'Chicken Pesto Pasta',
#        'Coq au Vin', 'Eggplant and Chickpea Curry', 'Espresso Martini',
#        'Ginger Soy Glazed Chicken', 'Honey Sriracha Chicken Bites',
#        'Lamb Kebabs', 'Lemon Herb Grilled Salmon', 'Mango Chicken Quesadillas',
#        'Mango Salsa with Avocado', 'Peach Melba', 'Pineapple Ginger Smoothie',
#        'Pulled Pork Sliders', 'Raspberry Almond Tart',
#        'Spinach and Feta Stuffed Chicken', 'Strawberry Basil Sparkler',
#        'Teriyaki Glazed Edamame', 'Thai Peanut Noodles', 'Truffle Fries',
#        'Vegetable Minestrone Soup'],
#       dtype='object', name='ItemName')

# %%
#filtered_rating in famous_items
final_ratings = filtered_rating[filtered_rating['ItemName'].isin(famous_items)]
final_ratings.drop_duplicates()
# Out:
#       user_id  ItemID  rating    Category                   ItemName  \
# 433       392       1       5  Appetizers              Caprese Salad
# 458        44       1       3  Appetizers              Caprese Salad
# 460       132       1       2  Appetizers              Caprese Salad
# 464       102       1       2  Appetizers              Caprese Salad
# 1569      132      28       1       Lunch  Vegetable Minestrone Soup
# ...       ...     ...     ...         ...                        ...
# 7015      388     156       7    Desserts       Apple Cinnamon Crisp
# 7019      287     156       3    Desserts       Apple Cinnamon Crisp
# 7021       38     156       3    Desserts       Apple Cinnamon Crisp
# 7022      399     156       7    Desserts       Apple Cinnamon Crisp
# 7023      388     156       6    Desserts       Apple Cinnamon Crisp
#
#                                             Description   Price  \
# 433   Fresh tomatoes, mozzarella, basil, olive oil, ...  749.25
# 458   Fresh tomatoes, mozzarella, basil, olive oil, ...  749.25
# 460   Fresh tomatoes, mozzarella, basil, olive oil, ...  749.25
# 464   Fresh tomatoes, mozzarella, basil, olive oil, ...  749.25
# 1569  Hearty soup with assorted vegetables, beans, a...  486.75
# ...                                                 ...     ...
# 7015  Baked apple slices with a cinnamon and oat top...  561.75
# 7019  Baked apple slices with a cinnamon and oat top...  561.75
# 7021  Baked apple slices with a cinnamon and oat top...  561.75
# 7022  Baked apple slices with a cinnamon and oat top...  561.75
# 7023  Baked apple slices with a cinnamon and oat top...  561.75
#
#                      ImageURL
# 433   caprese_salad_image.jpg
# 458   caprese_salad_image.jpg
# 460   caprese_salad_image.jpg
# 464   caprese_salad_image.jpg
# 1569        lunch_image_8.jpg
# ...                       ...
# 7015     dessert_image_26.jpg
# 7019     dessert_image_26.jpg
# 7021     dessert_image_26.jpg
# 7022     dessert_image_26.jpg
# 7023     dessert_image_26.jpg
#
# [165 rows x 8 columns]

# %%
pt = final_ratings.pivot_table(index='ItemName', columns='user_id', values='rating')
pt
# Out:
# user_id                                38        44    102       132   135  \
# ItemName
# Apple Cinnamon Crisp              3.000000       NaN   NaN       NaN   NaN
# BBQ Pulled Pork Sandwich               NaN       NaN   NaN       NaN   NaN
# Bacon-Wrapped Jalapeños                NaN  6.000000   NaN       NaN   NaN
# Black Bean and Corn Salad         6.769231       NaN  6.00       NaN   NaN
# Blueberry Lavender Lemonade       4.142857  3.666667  3.16  5.705882  7.00
# Caprese Salad                          NaN  3.000000  2.00  2.000000   NaN
# Chicken Pesto Pasta               4.000000  3.000000   NaN       NaN   NaN
# Coq au Vin                             NaN       NaN   NaN       NaN   NaN
# Eggplant and Chickpea Curry            NaN       NaN   NaN       NaN   NaN
# Espresso Martini                  7.000000       NaN   NaN       NaN   NaN
# Ginger Soy Glazed Chicken              NaN       NaN  6.00       NaN  5.00
# Honey Sriracha Chicken Bites           NaN       NaN  6.00  6.000000   NaN
# Lamb Kebabs                            NaN       NaN   NaN       NaN   NaN
# Lemon Herb Grilled Salmon         6.000000  3.000000  7.00  5.000000  3.00
# Mango Chicken Quesadillas         4.153846       NaN   NaN       NaN   NaN
# Mango Salsa with Avocado               NaN  6.000000  7.00       NaN  3.00
# Peach Melba                            NaN       NaN   NaN       NaN  4.00
# Pineapple Ginger Smoothie              NaN       NaN   NaN       NaN   NaN
# Pulled Pork Sliders               4.333333  3.000000  3.00       NaN  3.75
# Raspberry Almond Tart                  NaN       NaN   NaN       NaN   NaN
# Spinach and Feta Stuffed Chicken       NaN       NaN   NaN       NaN   NaN
# Strawberry Basil Sparkler              NaN       NaN  7.00       NaN  3.00
# Teriyaki Glazed Edamame                NaN       NaN   NaN       NaN   NaN
# Thai Peanut Noodles               3.000000  4.000000  7.00       NaN   NaN
# Truffle Fries                          NaN       NaN   NaN       NaN   NaN
# Vegetable Minestrone Soup              NaN       NaN  4.00  1.000000   NaN
#
# user_id                                194  222  243  244  283       287  \
# ItemName
# Apple Cinnamon Crisp                   NaN  NaN  NaN  NaN  NaN  3.000000
# BBQ Pulled Pork Sandwich               NaN  NaN  NaN  NaN  NaN       NaN
# Bacon-Wrapped Jalapeños                NaN  NaN  NaN  3.0  NaN       NaN
# Black Bean and Corn Salad              NaN  7.0  NaN  3.0  NaN  4.000000
# Blueberry Lavender Lemonade       6.958333  5.0  NaN  7.0  NaN  4.000000
# Caprese Salad                          NaN  NaN  NaN  NaN  NaN       NaN
# Chicken Pesto Pasta               6.000000  NaN  NaN  3.0  NaN       NaN
# Coq au Vin                             NaN  NaN  NaN  NaN  NaN       NaN
# Eggplant and Chickpea Curry       1.000000  NaN  NaN  NaN  NaN       NaN
# Espresso Martini                       NaN  NaN  NaN  NaN  NaN       NaN
# Ginger Soy Glazed Chicken              NaN  6.0  6.0  NaN  NaN       NaN
# Honey Sriracha Chicken Bites           NaN  NaN  NaN  4.0  NaN       NaN
# Lamb Kebabs                            NaN  6.0  NaN  NaN  NaN       NaN
# Lemon Herb Grilled Salmon         6.000000  5.0  NaN  NaN  NaN  5.000000
# Mango Chicken Quesadillas              NaN  NaN  NaN  NaN  NaN       NaN
# Mango Salsa with Avocado               NaN  NaN  NaN  NaN  NaN       NaN
# Peach Melba                       7.000000  4.0  NaN  NaN  NaN       NaN
# Pineapple Ginger Smoothie              NaN  NaN  NaN  NaN  NaN       NaN
# Pulled Pork Sliders                    NaN  6.0  NaN  7.0  NaN  4.000000
# Raspberry Almond Tart                  NaN  NaN  NaN  NaN  NaN       NaN
# Spinach and Feta Stuffed Chicken       NaN  5.5  NaN  NaN  NaN  4.923077
# Strawberry Basil Sparkler         6.000000  NaN  NaN  NaN  NaN       NaN
# Teriyaki Glazed Edamame                NaN  NaN  5.0  NaN  NaN       NaN
# Thai Peanut Noodles                    NaN  NaN  NaN  7.0  NaN       NaN
# Truffle Fries                     6.000000  NaN  7.0  NaN  NaN       NaN
# Vegetable Minestrone Soup              NaN  NaN  2.0  NaN  2.0       NaN
#
# user_id                                297  306  326  364  376       388  391  \
# ItemName
# Apple Cinnamon Crisp                   NaN  NaN  NaN  NaN  NaN  6.076923  NaN
# BBQ Pulled Pork Sandwich          4.000000  NaN  NaN  NaN  NaN  3.000000  3.0
# Bacon-Wrapped Jalapeños                NaN  NaN  NaN  NaN  4.0       NaN  NaN
# Black Bean and Corn Salad         6.000000  NaN  NaN  NaN  NaN       NaN  6.0
# Blueberry Lavender Lemonade       4.896552  7.0  NaN  NaN  NaN  5.200000  NaN
# Caprese Salad                          NaN  NaN  NaN  NaN  NaN       NaN  NaN
# Chicken Pesto Pasta                    NaN  NaN  NaN  1.0  NaN       NaN  NaN
# Coq au Vin                             NaN  NaN  NaN  NaN  NaN       NaN  NaN
# Eggplant and Chickpea Curry            NaN  NaN  NaN  1.0  NaN       NaN  1.0
# Espresso Martini                  3.000000  7.0  NaN  NaN  NaN       NaN  NaN
# Ginger Soy Glazed Chicken              NaN  NaN  NaN  NaN  NaN       NaN  NaN
# Honey Sriracha Chicken Bites           NaN  NaN  4.0  NaN  NaN  6.000000  NaN
# Lamb Kebabs                            NaN  7.0  NaN  NaN  NaN  4.000000  NaN
# Lemon Herb Grilled Salmon         6.578947  7.0  NaN  NaN  6.0  3.666667  NaN
# Mango Chicken Quesadillas              NaN  NaN  NaN  NaN  4.0       NaN  NaN
# Mango Salsa with Avocado               NaN  7.0  NaN  NaN  NaN  4.000000  NaN
# Peach Melba                       6.000000  NaN  NaN  NaN  NaN       NaN  NaN
# Pineapple Ginger Smoothie              NaN  3.0  NaN  NaN  NaN  3.000000  NaN
# Pulled Pork Sliders               4.000000  NaN  NaN  NaN  NaN  5.444444  NaN
# Raspberry Almond Tart                  NaN  NaN  NaN  NaN  NaN       NaN  NaN
# Spinach and Feta Stuffed Chicken  7.000000  NaN  NaN  NaN  NaN       NaN  NaN
# Strawberry Basil Sparkler         5.666667  3.0  NaN  NaN  NaN  3.666667  NaN
# Teriyaki Glazed Edamame           4.000000  NaN  4.0  NaN  4.0       NaN  NaN
# Thai Peanut Noodles               2.000000  NaN  NaN  NaN  NaN       NaN  NaN
# Truffle Fries                          NaN  3.0  NaN  NaN  NaN  3.000000  NaN
# Vegetable Minestrone Soup              NaN  NaN  NaN  NaN  NaN       NaN  NaN
#
# user_id                           392       399
# ItemName
# Apple Cinnamon Crisp              NaN  7.000000
# BBQ Pulled Pork Sandwich          NaN       NaN
# Bacon-Wrapped Jalapeños           NaN  4.000000
# Black Bean and Corn Salad         NaN  5.000000
# Blueberry Lavender Lemonade       NaN  5.500000
# Caprese Salad                     5.0       NaN
# Chicken Pesto Pasta               NaN       NaN
# Coq au Vin                        3.0       NaN
# Eggplant and Chickpea Curry       NaN  6.000000
# Espresso Martini                  NaN       NaN
# Ginger Soy Glazed Chicken         NaN  7.000000
# Honey Sriracha Chicken Bites      NaN       NaN
# Lamb Kebabs                       NaN  7.000000
# Lemon Herb Grilled Salmon         6.0  4.000000
# Mango Chicken Quesadillas         4.0  1.000000
# Mango Salsa with Avocado          3.0  3.000000
# Peach Melba                       NaN       NaN
# Pineapple Ginger Smoothie         NaN       NaN
# Pulled Pork Sliders               NaN  7.000000
# Raspberry Almond Tart             NaN  3.076923
# Spinach and Feta Stuffed Chicken  NaN       NaN
# Strawberry Basil Sparkler         NaN  5.333333
# Teriyaki Glazed Edamame           NaN       NaN
# Thai Peanut Noodles               4.0       NaN
# Truffle Fries                     NaN  5.000000
# Vegetable Minestrone Soup         9.0       NaN

# %%
pt.fillna(0,inplace = True)
pt #items as rows and users as columns
# Out:
# user_id                                38        44    102       132   135  \
# ItemName
# Apple Cinnamon Crisp              3.000000  0.000000  0.00  0.000000  0.00
# BBQ Pulled Pork Sandwich          0.000000  0.000000  0.00  0.000000  0.00
# Bacon-Wrapped Jalapeños           0.000000  6.000000  0.00  0.000000  0.00
# Black Bean and Corn Salad         6.769231  0.000000  6.00  0.000000  0.00
# Blueberry Lavender Lemonade       4.142857  3.666667  3.16  5.705882  7.00
# Caprese Salad                     0.000000  3.000000  2.00  2.000000  0.00
# Chicken Pesto Pasta               4.000000  3.000000  0.00  0.000000  0.00
# Coq au Vin                        0.000000  0.000000  0.00  0.000000  0.00
# Eggplant and Chickpea Curry       0.000000  0.000000  0.00  0.000000  0.00
# Espresso Martini                  7.000000  0.000000  0.00  0.000000  0.00
# Ginger Soy Glazed Chicken         0.000000  0.000000  6.00  0.000000  5.00
# Honey Sriracha Chicken Bites      0.000000  0.000000  6.00  6.000000  0.00
# Lamb Kebabs                       0.000000  0.000000  0.00  0.000000  0.00
# Lemon Herb Grilled Salmon         6.000000  3.000000  7.00  5.000000  3.00
# Mango Chicken Quesadillas         4.153846  0.000000  0.00  0.000000  0.00
# Mango Salsa with Avocado          0.000000  6.000000  7.00  0.000000  3.00
# Peach Melba                       0.000000  0.000000  0.00  0.000000  4.00
# Pineapple Ginger Smoothie         0.000000  0.000000  0.00  0.000000  0.00
# Pulled Pork Sliders               4.333333  3.000000  3.00  0.000000  3.75
# Raspberry Almond Tart             0.000000  0.000000  0.00  0.000000  0.00
# Spinach and Feta Stuffed Chicken  0.000000  0.000000  0.00  0.000000  0.00
# Strawberry Basil Sparkler         0.000000  0.000000  7.00  0.000000  3.00
# Teriyaki Glazed Edamame           0.000000  0.000000  0.00  0.000000  0.00
# Thai Peanut Noodles               3.000000  4.000000  7.00  0.000000  0.00
# Truffle Fries                     0.000000  0.000000  0.00  0.000000  0.00
# Vegetable Minestrone Soup         0.000000  0.000000  4.00  1.000000  0.00
#
# user_id                                194  222  243  244  283       287  \
# ItemName
# Apple Cinnamon Crisp              0.000000  0.0  0.0  0.0  0.0  3.000000
# BBQ Pulled Pork Sandwich          0.000000  0.0  0.0  0.0  0.0  0.000000
# Bacon-Wrapped Jalapeños           0.000000  0.0  0.0  3.0  0.0  0.000000
# Black Bean and Corn Salad         0.000000  7.0  0.0  3.0  0.0  4.000000
# Blueberry Lavender Lemonade       6.958333  5.0  0.0  7.0  0.0  4.000000
# Caprese Salad                     0.000000  0.0  0.0  0.0  0.0  0.000000
# Chicken Pesto Pasta               6.000000  0.0  0.0  3.0  0.0  0.000000
# Coq au Vin                        0.000000  0.0  0.0  0.0  0.0  0.000000
# Eggplant and Chickpea Curry       1.000000  0.0  0.0  0.0  0.0  0.000000
# Espresso Martini                  0.000000  0.0  0.0  0.0  0.0  0.000000
# Ginger Soy Glazed Chicken         0.000000  6.0  6.0  0.0  0.0  0.000000
# Honey Sriracha Chicken Bites      0.000000  0.0  0.0  4.0  0.0  0.000000
# Lamb Kebabs                       0.000000  6.0  0.0  0.0  0.0  0.000000
# Lemon Herb Grilled Salmon         6.000000  5.0  0.0  0.0  0.0  5.000000
# Mango Chicken Quesadillas         0.000000  0.0  0.0  0.0  0.0  0.000000
# Mango Salsa with Avocado          0.000000  0.0  0.0  0.0  0.0  0.000000
# Peach Melba                       7.000000  4.0  0.0  0.0  0.0  0.000000
# Pineapple Ginger Smoothie         0.000000  0.0  0.0  0.0  0.0  0.000000
# Pulled Pork Sliders               0.000000  6.0  0.0  7.0  0.0  4.000000
# Raspberry Almond Tart             0.000000  0.0  0.0  0.0  0.0  0.000000
# Spinach and Feta Stuffed Chicken  0.000000  5.5  0.0  0.0  0.0  4.923077
# Strawberry Basil Sparkler         6.000000  0.0  0.0  0.0  0.0  0.000000
# Teriyaki Glazed Edamame           0.000000  0.0  5.0  0.0  0.0  0.000000
# Thai Peanut Noodles               0.000000  0.0  0.0  7.0  0.0  0.000000
# Truffle Fries                     6.000000  0.0  7.0  0.0  0.0  0.000000
# Vegetable Minestrone Soup         0.000000  0.0  2.0  0.0  2.0  0.000000
#
# user_id                                297  306  326  364  376       388  391  \
# ItemName
# Apple Cinnamon Crisp              0.000000  0.0  0.0  0.0  0.0  6.076923  0.0
# BBQ Pulled Pork Sandwich          4.000000  0.0  0.0  0.0  0.0  3.000000  3.0
# Bacon-Wrapped Jalapeños           0.000000  0.0  0.0  0.0  4.0  0.000000  0.0
# Black Bean and Corn Salad         6.000000  0.0  0.0  0.0  0.0  0.000000  6.0
# Blueberry Lavender Lemonade       4.896552  7.0  0.0  0.0  0.0  5.200000  0.0
# Caprese Salad                     0.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Chicken Pesto Pasta               0.000000  0.0  0.0  1.0  0.0  0.000000  0.0
# Coq au Vin                        0.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Eggplant and Chickpea Curry       0.000000  0.0  0.0  1.0  0.0  0.000000  1.0
# Espresso Martini                  3.000000  7.0  0.0  0.0  0.0  0.000000  0.0
# Ginger Soy Glazed Chicken         0.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Honey Sriracha Chicken Bites      0.000000  0.0  4.0  0.0  0.0  6.000000  0.0
# Lamb Kebabs                       0.000000  7.0  0.0  0.0  0.0  4.000000  0.0
# Lemon Herb Grilled Salmon         6.578947  7.0  0.0  0.0  6.0  3.666667  0.0
# Mango Chicken Quesadillas         0.000000  0.0  0.0  0.0  4.0  0.000000  0.0
# Mango Salsa with Avocado          0.000000  7.0  0.0  0.0  0.0  4.000000  0.0
# Peach Melba                       6.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Pineapple Ginger Smoothie         0.000000  3.0  0.0  0.0  0.0  3.000000  0.0
# Pulled Pork Sliders               4.000000  0.0  0.0  0.0  0.0  5.444444  0.0
# Raspberry Almond Tart             0.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Spinach and Feta Stuffed Chicken  7.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Strawberry Basil Sparkler         5.666667  3.0  0.0  0.0  0.0  3.666667  0.0
# Teriyaki Glazed Edamame           4.000000  0.0  4.0  0.0  4.0  0.000000  0.0
# Thai Peanut Noodles               2.000000  0.0  0.0  0.0  0.0  0.000000  0.0
# Truffle Fries                     0.000000  3.0  0.0  0.0  0.0  3.000000  0.0
# Vegetable Minestrone Soup         0.000000  0.0  0.0  0.0  0.0  0.000000  0.0
#
# user_id                           392       399
# ItemName
# Apple Cinnamon Crisp              0.0  7.000000
# BBQ Pulled Pork Sandwich          0.0  0.000000
# Bacon-Wrapped Jalapeños           0.0  4.000000
# Black Bean and Corn Salad         0.0  5.000000
# Blueberry Lavender Lemonade       0.0  5.500000
# Caprese Salad                     5.0  0.000000
# Chicken Pesto Pasta               0.0  0.000000
# Coq au Vin                        3.0  0.000000
# Eggplant and Chickpea Curry       0.0  6.000000
# Espresso Martini                  0.0  0.000000
# Ginger Soy Glazed Chicken         0.0  7.000000
# Honey Sriracha Chicken Bites      0.0  0.000000
# Lamb Kebabs                       0.0  7.000000
# Lemon Herb Grilled Salmon         6.0  4.000000
# Mango Chicken Quesadillas         4.0  1.000000
# Mango Salsa with Avocado          3.0  3.000000
# Peach Melba                       0.0  0.000000
# Pineapple Ginger Smoothie         0.0  0.000000
# Pulled Pork Sliders               0.0  7.000000
# Raspberry Almond Tart             0.0  3.076923
# Spinach and Feta Stuffed Chicken  0.0  0.000000
# Strawberry Basil Sparkler         0.0  5.333333
# Teriyaki Glazed Edamame           0.0  0.000000
# Thai Peanut Noodles               4.0  0.000000
# Truffle Fries                     0.0  5.000000
# Vegetable Minestrone Soup         9.0  0.000000

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(pt.corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %%
#find out the similar items
from sklearn.metrics.pairwise import cosine_similarity

# %%
# food item compared to all other food items (ABxBA)
similarity_scores = cosine_similarity(pt)
similarity_scores.shape
#euclidian distance of (26x26) items
# Out:
# (26, 26)

# %%
#MAIN RECOMMENDER SYSTEM
# Recommends similar items based on a similarity matrix (pt).
#   Args:
#       ItemName: The name of the item for which to recommend similar items.
#   Returns:
#       None (prints the recommended item names).

def recommend(ItemName):
    #index fetch
    index = np.where(pt.index == ItemName )[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key = lambda x:x[1],reverse = True)[1:6]
    
    
    data = []
    for i in similar_items:
        item = []
        temp_df = menu[menu['ItemName'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('ItemName')['ItemName'].values))
        item.extend(list(temp_df.drop_duplicates('ItemName')['Description'].values))
        item.extend(list(temp_df.drop_duplicates('ItemName')['ImageURL'].values))
        item.extend(list(temp_df.drop_duplicates('ItemName')['Price'].values))
        
        data.append(item)
    
    return data

# %%
recommend('Pulled Pork Sliders')
# Out:
# [['Blueberry Lavender Lemonade',
#   'Lemonade with blueberry and lavender flavors for a unique twist.',
#   'beverage_image_20.jpg',
#   336.75],
#  ['Black Bean and Corn Salad',
#   'Black beans, corn, red onion, and cilantro tossed in a lime vinaigrette.',
#   'lunch_image_22.jpg',
#   636.75],
#  ['Apple Cinnamon Crisp',
#   'Baked apple slices with a cinnamon and oat topping, served with vanilla bean ice cream.',
#   'dessert_image_26.jpg',
#   561.75],
#  ['Lemon Herb Grilled Salmon',
#   'Grilled salmon fillet marinated in lemon, herbs, and garlic, served with roasted vegetables.',
#   'dinner_image_21.jpg',
#   1249.25],
#  ['Ginger Soy Glazed Chicken',
#   'Chicken thighs glazed in a ginger soy sauce, served with jasmine rice and steamed broccoli.',
#   'dinner_image_23.jpg',
#   1361.75]]

# %%
#returns the index position of any item in 'pivot table(pt)'
#np.where(pt.index == 'BLT Sandwich')[0][0]

# %%
#item index will also be available within distance - enumerate
#list(enumerate(similarity_scores[0]))

# %%
#sorting on the basis or similairty score (most similar items will be on top)(item no 1-4 will be displayed)
#sorted(list(enumerate(similarity_scores[0])),key = lambda x:x[1],reverse = True)[1:4]
#paste this entire thing in similar items

# %%
item_count = len(popular_df)  # Get the number of items

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb')) 
#write-binary

# %%
pickle.dump(pt,open('pt.pkl','wb')) 
pickle.dump(menu,open('menu.pkl','wb')) 
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb')) 
pickle.dump(item_count,open('item_count.pkl','wb'))

# %%
popular_df.columns
# Out:
# Index(['ItemName', 'Description', 'Price', 'ImageURL', 'num_ratings',
#        'avg_ratings'],
#       dtype='object')
